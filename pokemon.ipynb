# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pokemons = pd.read_csv('pokemon_data.csv')
pokemons_xlsx = pd.read_excel('pokemon_data.xlsx')
pokemons_txt = pd.read_csv('pokemon_data.txt', delimiter='\t')

# %%
pokemon_Copy = pokemons.copy()
pokemon_Copy
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokemons.head(6)
# pokemons_txt.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False

# %%
pokemons.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
pokemons.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
for index, row in pokemons.iterrows():
    print(index, row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
 pokemons.Name[100:110]
# Out:
# 100              Haunter
# 101               Gengar
# 102    GengarMega Gengar
# 103                 Onix
# 104              Drowzee
# 105                Hypno
# 106               Krabby
# 107              Kingler
# 108              Voltorb
# 109            Electrode
# Name: Name, dtype: object

# %%
pokemons.iloc[1:5, :4 ]
# Out:
#    #                   Name Type 1  Type 2
# 1  2                Ivysaur  Grass  Poison
# 2  3               Venusaur  Grass  Poison
# 3  3  VenusaurMega Venusaur  Grass  Poison
# 4  4             Charmander   Fire     NaN

# %%
pokemons.loc[:, 'Name':'Type 2']
# Out:
#                       Name   Type 1  Type 2
# 0                Bulbasaur    Grass  Poison
# 1                  Ivysaur    Grass  Poison
# 2                 Venusaur    Grass  Poison
# 3    VenusaurMega Venusaur    Grass  Poison
# 4               Charmander     Fire     NaN
# ..                     ...      ...     ...
# 795                Diancie     Rock   Fairy
# 796    DiancieMega Diancie     Rock   Fairy
# 797    HoopaHoopa Confined  Psychic   Ghost
# 798     HoopaHoopa Unbound  Psychic    Dark
# 799              Volcanion     Fire   Water
#
# [800 rows x 3 columns]

# %%
pokemons.loc[(pokemons['Type 1'] == 'Grass') & (pokemons[ 'Type 2'] == 'Poison') & (pokemons.HP > 50)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 452  407               Roserade  Grass  Poison   60      70       65      125
# 651  590                Foongus  Grass  Poison   69      55       45       55
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary
# 1         80     60           1      False
# ...

# %%
favoritePokemons = pokemons.loc[(pokemons['Type 1'] == 'Grass') & (pokemons[ 'Type 2'] == 'Poison') & (pokemons.HP > 50)]
favoritePokemons.reset_index(drop=True, inplace=True)
# favoritePokemons = favoritePokemons.drop(columns='index')
favoritePokemons
# Out:
#      #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0    2                Ivysaur  Grass  Poison   60      62       63       80
# 1    3               Venusaur  Grass  Poison   80      82       83      100
# 2    3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 3   44                  Gloom  Grass  Poison   60      65       70       85
# 4   45              Vileplume  Grass  Poison   75      80       85      110
# 5   70             Weepinbell  Grass  Poison   65      90       50       85
# 6   71             Victreebel  Grass  Poison   80     105       65      100
# 7  407               Roserade  Grass  Poison   60      70       65      125
# 8  590                Foongus  Grass  Poison   69      55       45       55
# 9  591              Amoonguss  Grass  Poison  114      85       70       85
#
#    Sp. Def  Speed  Generation  Legendary
# 0       80     60           1      False
# 1      100     80           1      False
# ...

# %%
babyPokemons = pokemons.loc[~pokemons['Name'].str.contains('Mega')]
babyPokemons.reset_index(drop=True, inplace=True)
babyPokemons
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1            Bulbasaur    Grass  Poison   45      49       49       65
# 1      2              Ivysaur    Grass  Poison   60      62       63       80
# 2      3             Venusaur    Grass  Poison   80      82       83      100
# 3      4           Charmander     Fire     NaN   39      52       43       60
# 4      5           Charmeleon     Fire     NaN   58      64       58       80
# ..   ...                  ...      ...     ...  ...     ...      ...      ...
# 746  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 747  719              Diancie     Rock   Fairy   50     100      150      100
# 748  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 749  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 750  721            Volcanion     Fire   Water   80     110      120      130
#
# ...

# %%
import re

pokemons.loc[pokemons['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
pokemons.loc[pokemons['Name'].str.contains('^pi+', flags=re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %%
pokemons.loc[pokemons['Type 1'] == 'Electric', 'Type 1'] = 'Lightning'
# pokemons.loc[pokemons['Type 1'] == 'Lightning', 'Legendary'] = True
pokemons.loc[pokemons['HP'] < 50, ['Generation', 'Legendary']] = ['Test', 'Value']
pokemons.loc[pokemons['Type 1'] == 'Lightning']
# Out:
#        #                      Name     Type 1  Type 2  HP  Attack  Defense  \
# 30    25                   Pikachu  Lightning     NaN  35      55       40
# 31    26                    Raichu  Lightning     NaN  60      90       55
# 88    81                 Magnemite  Lightning   Steel  25      35       70
# 89    82                  Magneton  Lightning   Steel  50      60       95
# 108  100                   Voltorb  Lightning     NaN  40      30       50
# 109  101                 Electrode  Lightning     NaN  60      50       70
# 134  125                Electabuzz  Lightning     NaN  65      83       57
# 146  135                   Jolteon  Lightning     NaN  65      65       60
# 157  145                    Zapdos  Lightning  Flying  90      90       85
# 186  172                     Pichu  Lightning     NaN  20      40       15
# 193  179                    Mareep  Lightning     NaN  55      40       40
# ...

# %%
pokemons.sort_values('Name', ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
 pokemons.sort_values(['Type 1', 'HP'], ascending=[1, 0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
 pokemons.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
#  pokemons['Total'] = pokemons.HP + pokemons.Attack + pokemons.Defense + pokemons['Sp. Atk'] + pokemons['Sp. Def'] + pokemons['Speed']
pokemons['Total'] = pokemons.iloc[:, 4:10].sum(axis=1)

# %%
pokeShort1 = pokemons.drop(columns=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'])
pokeShort1.sort_values('Total', ascending=0)
# Out:
#        #                   Name   Type 1    Type 2  Generation  Legendary  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying           3       True
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN           1       True
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting           1       True
# 422  382    KyogrePrimal Kyogre    Water       NaN           3       True
# 424  383  GroudonPrimal Groudon   Ground      Fire           3       True
# ..   ...                    ...      ...       ...         ...        ...
# 13    10               Caterpie      Bug       NaN           1      False
# 288  265                Wurmple      Bug       NaN           3      False
# 446  401              Kricketot      Bug       NaN           4      False
# 322  298                Azurill   Normal     Fairy           3      False
# 206  191                Sunkern    Grass       NaN           2      False
#
#      Total
# 426    780
# 164    780
# 163    780
# 422    770
# 424    770
# ...

# %%
# pokeShort1[pokeShort1['Type 1'] == 'Electric', 'Legendary'] = True
print(type(pokeShort1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# pokeNew = pokemons[list(pokemons.columns[0:4])]
cols = list(pokemons.columns)
pokeNew = pokemons[cols[0:4] + [cols[-1]] + cols[4:12]]

# %%
print(type(pokeNew))
print(type(pokemons))
pokeNew.to_csv('pokemons_modified.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
pokeNew.to_excel('pokemons_modified.xlsx', index=False)

# %%
pokeNew.to_csv('pokemons_modified.txt', index=False, sep='\t')

# %%
pokemons = pd.read_csv('pokemons_modified.csv')

# %%
pokemons.groupby('Type 1').mean().sort_values('HP', ascending=False)
# Out:
#                     #       Total         HP      Attack     Defense  \
# Type 1
# Dragon     474.375000  550.531250  83.312500  112.125000   86.375000
# Normal     319.173469  401.683673  77.275510   73.469388   59.846939
# Fairy      449.529412  413.176471  74.117647   61.529412   65.705882
# Ground     356.281250  437.500000  73.781250   95.750000   84.843750
# Water      303.089286  430.455357  72.062500   74.151786   72.946429
# Ice        423.541667  433.458333  72.000000   72.750000   71.416667
# Flying     677.750000  485.000000  70.750000   78.750000   66.250000
# Psychic    380.807018  475.947368  70.631579   71.456140   67.684211
# Fire       327.403846  458.076923  69.903846   84.769231   67.769231
# Fighting   363.851852  416.444444  69.851852   96.777778   65.925926
# Grass      344.871429  421.142857  67.271429   73.214286   70.800000
# Poison     251.785714  399.142857  67.250000   74.678571   68.821429
# ...

# %%
pokemons['Count'] = 1
pokemons.groupby(['Type 1', 'Type 2']).count()['Count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: Count, Length: 136, dtype: int64

# %%
new_df = pd.DataFrame(columns=pokemons.columns)
for df in pd.read_csv('pokemons_modified.csv', chunksize=10):
    result = df.groupby('Type 1').count()
    new_df = pd.concat([new_df, result])
new_df[['Type 1', 'Type 2', 'Count']]
# Out:
#         Type 1 Type 2 Count
# Fire       NaN      3   NaN
# Grass      NaN      4   NaN
# Water      NaN      0   NaN
# Bug        NaN      5   NaN
# Water      NaN      0   NaN
# ...        ...    ...   ...
# Fairy      NaN      0   NaN
# Fire       NaN      1   NaN
# Flying     NaN      2   NaN
# Psychic    NaN      2   NaN
# Rock       NaN      2   NaN
#
# [361 rows x 3 columns]
